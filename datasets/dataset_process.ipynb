# %%
from datasets import load_dataset
from pathlib import Path

# 1. Load from Hugging Face Hub
ds = load_dataset("wenkai-li/big5_chat")

# 2. (Optionally) inspect splits
print(ds)  
# e.g., DatasetDict({'train': Dataset(...), 'test': Dataset(...)})  — depends on how big5_chat is organized

# 3. Create local target directory
target_dir = Path("/scratch/xuyuan/code/PersonalTrait/datasets/bigfive")
target_dir.mkdir(parents=True, exist_ok=True)

# 4. Save to disk (Arrow format by default)
ds.save_to_disk(str(target_dir))
print("Saved to", target_dir)
# Out:
# Generating train split:   0%|          | 0/100000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['env_idx', 'trait', 'level', 'train_instruction', 'train_input', 'train_output', 'head', 'relation', 'tail', 'literal', 'narrative', 'personx', 'persony', 'original_index'],
#         num_rows: 100000
#     })
# })
# Saving the dataset (0/1 shards):   0%|          | 0/100000 [00:00<?, ? examples/s]
# Saved to /scratch/xuyuan/code/PersonalTrait/datasets/bigfive

# %%
import torch

res=torch.load("/scratch/xuyuan/code/PersonalTrait/activation/bigfive/llama_3_8b_layer15_no_answer_last.pt")
print(len(res))
print(res[0].shape)
# Out:
# 1000
# torch.Size([4096])
